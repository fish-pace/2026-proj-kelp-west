# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import cartopy
import cartopy.crs as ccrs
from matplotlib import colors
from scipy.integrate import trapezoid
from scipy.spatial import cKDTree
from matplotlib.colors import Normalize

# %%
sites = pd.read_csv('data/PISCOSites.csv')
sites
# Out:
#                method                    site   latitude   longitude  \
# 0    SBTL_SWATH_PISCO                   PINOS  36.640454 -121.928734
# 1    SBTL_SWATH_PISCO                   SIREN  36.630733 -121.918590
# 2    SBTL_SWATH_PISCO           CYPRESS_PT_DC  36.579645 -121.982468
# 3    SBTL_SWATH_PISCO               LONE_TREE  36.566418 -121.970688
# 4    SBTL_SWATH_PISCO             OTTER_PT_DC  36.636484 -121.921162
# ..                ...                     ...        ...         ...
# 139  SBTL_SWATH_PISCO   SCI_SAN_PEDRO_POINT_W  34.042250 -119.531600
# 140  SBTL_SWATH_PISCO    SCI_POTATO_PASTURE_W  34.052233 -119.582533
# 141  SBTL_SWATH_PISCO    SCI_POTATO_PASTURE_W  34.052167 -119.582117
# 142  SBTL_SWATH_PISCO  SCI_SCORPION_ANCHORAGE  34.047983 -119.551400
# 143  SBTL_SWATH_PISCO  SCI_SCORPION_ANCHORAGE  34.047983 -119.551400
#
#                            MPA_Name mpa_type site_status
# 0    Lovers Point - Julia Platt SMR      SMR   reference
# 1    Lovers Point - Julia Platt SMR      SMR   reference
# 2                   Carmel Bay SMCA     SMCA   reference
# 3                   Carmel Bay SMCA     SMCA   reference
# 4    Lovers Point - Julia Platt SMR      SMR   reference
# ..                              ...      ...         ...
# 139                    Scorpion SMR      SMR   reference
# 140                    Scorpion SMR      SMR         mpa
# 141                    Scorpion SMR      SMR         mpa
# 142                    Scorpion SMR      SMR         mpa
# 143                    Scorpion SMR      SMR         mpa
#
# [144 rows x 7 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw={"projection": ccrs.PlateCarree()})
ax.gridlines(draw_labels=True)
ax.coastlines()
ax.set_extent([-120.5, -119.25, 33.8, 34.5], crs=ccrs.PlateCarree())
ax.scatter(sites['longitude'], sites['latitude'], s=10)
