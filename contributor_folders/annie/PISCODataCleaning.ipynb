# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import cartopy
import cartopy.crs as ccrs
from matplotlib import colors
from scipy.integrate import trapezoid
from scipy.spatial import cKDTree
from matplotlib.colors import Normalize

# %%
pisco = pd.read_csv('contributor_folders/annie/PISCO_kelpforest_swath.1.11.csv', encoding='windows-1252')
# Out:
# /tmp/ipykernel_236/2558463444.py:1: DtypeWarning: Columns (12,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   pisco = pd.read_csv('contributor_folders/annie/PISCO_kelpforest_swath.1.11.csv', encoding='windows-1252')

# %%
pisco.head()
# Out:
#   campus            method  survey_year  year  month  day        site   zone  \
# 0   UCSC  SBTL_SWATH_PISCO         1999  1999      9    7  HOPKINS_DC  INNER
# 1   UCSC  SBTL_SWATH_PISCO         1999  1999      9    7  HOPKINS_DC  INNER
# 2   UCSC  SBTL_SWATH_PISCO         1999  1999      9    7  HOPKINS_DC  INNER
# 3   UCSC  SBTL_SWATH_PISCO         1999  1999      9    7  HOPKINS_DC  INNER
# 4   UCSC  SBTL_SWATH_PISCO         1999  1999      9    7  HOPKINS_DC  INNER
#
#    transect classcode  count  size disease         observer  depth notes  \
# 0         1    CRYSTE      1   NaN     NaN  STACEY BUCKELEW    6.1   NaN
# 1         1    DICSPP      2   NaN     NaN  STACEY BUCKELEW    6.1   NaN
# 2         1  MACPYRAD      2   2.0     NaN  STACEY BUCKELEW    6.1   NaN
# 3         1  MACPYRAD      1   5.0     NaN  STACEY BUCKELEW    6.1   NaN
# 4         1  MACPYRAD      1   7.0     NaN  STACEY BUCKELEW    6.1   NaN
#
#   site_name_old
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
pisco = pisco.drop(columns=['campus', 'survey_year', 'disease', 'observer', 'notes', 'site_name_old'])

# %%
pisco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285808 entries, 0 to 285807
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   method     285808 non-null  object
#  1   year       285808 non-null  int64
#  2   month      285808 non-null  int64
#  3   day        285808 non-null  int64
#  4   site       285808 non-null  object
#  5   zone       285808 non-null  object
#  6   transect   285808 non-null  int64
#  7   classcode  285808 non-null  object
#  8   count      285808 non-null  int64
#  9   size       112664 non-null  float64
#  10  depth      265489 non-null  float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 24.0+ MB

# %%
piscoTaxon = pd.read_csv('contributor_folders/annie/PISCO_kelpforest_taxon_table.1.11.csv', encoding='windows-1252')
piscoTaxon.head()
# Out:
#   campus sample_type sample_subtype classcode   Kingdom    Phylum  \
# 0   UCSB        FISH           FISH      AARG  Animalia  Chordata
# 1   UCSB        FISH           FISH      ACOR  Animalia  Chordata
# 2   UCSC        FISH           FISH      ACOR  Animalia  Chordata
# 3   UCSB        FISH           FISH      ADAV  Animalia  Chordata
# 4   UCSC        FISH           FISH      ADAV  Animalia  Chordata
#
#             Class            Order        Family         Genus  ...  \
# 0  Actinopterygii      Perciformes  Embiotocidae  Amphistichus  ...
# 1  Actinopterygii  Scorpaeniformes      Cottidae      Artedius  ...
# 2  Actinopterygii  Scorpaeniformes      Cottidae      Artedius  ...
# 3  Actinopterygii      Perciformes    Haemulidae   Anisotremus  ...
# 4  Actinopterygii      Perciformes    Haemulidae   Anisotremus  ...
#
#   LOOKED2015 LOOKED2016 LOOKED2017 LOOKED2018 LOOKED2019 LOOKED2020  \
# 0        yes        yes        yes        yes        yes        yes
# 1         no         no         no         no         no         no
# 2         no         no         no         no         no         no
# 3        yes        yes        yes        yes        yes        yes
# 4        yes        yes        yes        yes        yes        yes
#
#   LOOKED2021 LOOKED2022 LOOKED2023 LOOKED2024
# 0        yes        yes        yes        yes
# 1         no         no         no         no
# 2         no         no         no         no
# 3        yes        yes        yes        yes
# 4        yes        yes        yes        yes
#
# [5 rows x 43 columns]

# %%
algaeInfo = piscoTaxon[(piscoTaxon['sample_type'] == 'SWATH') & (piscoTaxon['sample_subtype'] == 'ALGAE') & (piscoTaxon['LOOKED2024']=='yes')]

# %%
algaeInfo = algaeInfo.drop(columns=['campus', 'sample_type', 'sample_subtype', 'taxonomic_source', 'taxonomic_id', 'notes'])

# %%
kelpCodes = algaeInfo['classcode'].unique()

# %%
kelpCodes
# Out:
# array(['ALAMAR', 'COSCOS', 'EISARBAD', 'EISARBADSUB', 'EISARBJUV',
#        'HEDSES', 'LAMFAR', 'LAMREC', 'LAMSETAD', 'LAMSETADSUB',
#        'LAMSETJUV', 'LAMSTUMP', 'MACPYRAD', 'MACPYRJUV', 'MACPYRREC',
#        'NEOFIM', 'NERLUE', 'NERLUEJUV', 'PELPOR', 'PLEGAR', 'PTECALAD',
#        'PTECALADSUB', 'PTECALJUV', 'SACLAT', 'STEOSMAD', 'UNDPIN'],
#       dtype=object)

# %%
piscoKelp = pisco[pisco['classcode'].isin(kelpCodes)]

# %%
piscoKelp
# Out:
#                   method  year  month  day                    site   zone  \
# 2       SBTL_SWATH_PISCO  1999      9    7              HOPKINS_DC  INNER
# 3       SBTL_SWATH_PISCO  1999      9    7              HOPKINS_DC  INNER
# 4       SBTL_SWATH_PISCO  1999      9    7              HOPKINS_DC  INNER
# 5       SBTL_SWATH_PISCO  1999      9    7              HOPKINS_DC  INNER
# 6       SBTL_SWATH_PISCO  1999      9    7              HOPKINS_DC  INNER
# ...                  ...   ...    ...  ...                     ...    ...
# 285795  SBTL_SWATH_PISCO  2024     11    1  SCI_SCORPION_ANCHORAGE  OUTER
# 285796  SBTL_SWATH_PISCO  2024     11    1  SCI_SCORPION_ANCHORAGE  OUTER
# 285797  SBTL_SWATH_PISCO  2024     11    1  SCI_SCORPION_ANCHORAGE  OUTER
# 285798  SBTL_SWATH_PISCO  2024     11    1  SCI_SCORPION_ANCHORAGE  OUTER
# 285804  SBTL_SWATH_PISCO  2024     11    1  SCI_SCORPION_ANCHORAGE  OUTER
#
#         transect classcode  count  size  depth
# 2              1  MACPYRAD      2   2.0    6.1
# 3              1  MACPYRAD      1   5.0    6.1
# 4              1  MACPYRAD      1   7.0    6.1
# 5              1  MACPYRAD      1  16.0    6.1
# 6              1  MACPYRAD      1  17.0    6.1
# ...          ...       ...    ...   ...    ...
# 285795         2  MACPYRAD      2   9.0   11.6
# 285796         2  MACPYRAD      1  10.0   11.3
# 285797         2  MACPYRAD      1  11.0   12.2
# 285798         2  MACPYRAD      1  15.0   12.2
# 285804         2  STEOSMAD      2   NaN   11.3
#
# [92483 rows x 11 columns]

# %%
piscoSites = pd.read_csv('contributor_folders/annie/PISCO_kelpforest_site_table.1.11.csv', encoding='windows-1252')

# %%
piscoSites
# Out:
#       campus           method  survey_year                      site  \
# 0       UCSC  SBTL_FISH_PISCO         1999                HOPKINS_DC
# 1       UCSC  SBTL_FISH_PISCO         1999                HOPKINS_UC
# 2       UCSC  SBTL_FISH_PISCO         1999                MACABEE_UC
# 3       UCSC  SBTL_FISH_PISCO         1999                MACABEE_DC
# 4       UCSC  SBTL_FISH_PISCO         1999             STILLWATER_DC
# ...      ...              ...          ...                       ...
# 10400   UCSB  SBTL_QUAD_PISCO         2006                    COJO_E
# 10401   UCSB  SBTL_QUAD_PISCO         2009  ANACAPA_EAST_FISH_CAMP_E
# 10402   UCSB  SBTL_QUAD_PISCO         2009  ANACAPA_EAST_FISH_CAMP_E
# 10403   UCSB  SBTL_QUAD_PISCO         2006                  JALAMA_N
# 10404   UCSB  SBTL_QUAD_PISCO         2003                     SAL_S
#
#         latitude   longitude                        MPA_Name mpa_type  \
# 0      36.623586 -121.904196  Lovers Point - Julia Platt SMR      SMR
# 1      36.621649 -121.900789  Lovers Point - Julia Platt SMR      SMR
# 2      36.617148 -121.895695  Lovers Point - Julia Platt SMR      SMR
# 3      36.618184 -121.896835  Lovers Point - Julia Platt SMR      SMR
# 4      36.559729 -121.944014                 Carmel Bay SMCA     SMCA
# ...          ...         ...                             ...      ...
# 10400  34.441287 -120.416793            Point Conception SMR      SMR
# 10401  34.004500 -119.385783              Anacapa Island SMR      SMR
# 10402  34.004500 -119.385783              Anacapa Island SMR      SMR
# 10403  34.486960 -120.500523                  Vandenberg SMR      SMR
# 10404  34.871733 -120.630083                  Vandenberg SMR      SMR
#
#       site_status
# 0             mpa
# 1             mpa
# 2       reference
# 3       reference
# 4             mpa
# ...           ...
# 10400   reference
# 10401   reference
# 10402   reference
# 10403   reference
# 10404   reference
#
# [10405 rows x 9 columns]

# %%
piscoSites = piscoSites[piscoSites['survey_year'] == 2024]

# %%
piscoSites = piscoSites[piscoSites['method'].str.contains('SWATH')]

# %%
piscoSites = piscoSites.drop(columns=['campus', 'survey_year', 'method'])

# %%
piscoSites = piscoSites.drop_duplicates()

# %%
piscoSites.to_csv('data/PISCOSites.csv', index=False)

# %%
piscoSites
# Out:
#                         site   latitude   longitude  \
# 4537                   PINOS  36.640454 -121.928734
# 4538                   SIREN  36.630733 -121.918590
# 4539           CYPRESS_PT_DC  36.579645 -121.982468
# 4540               LONE_TREE  36.566418 -121.970688
# 4541             OTTER_PT_DC  36.636484 -121.921162
# ...                      ...        ...         ...
# 6315   SCI_SAN_PEDRO_POINT_W  34.042250 -119.531600
# 6316    SCI_POTATO_PASTURE_W  34.052233 -119.582533
# 6317    SCI_POTATO_PASTURE_W  34.052167 -119.582117
# 6318  SCI_SCORPION_ANCHORAGE  34.047983 -119.551400
# 6319  SCI_SCORPION_ANCHORAGE  34.047983 -119.551400
#
#                             MPA_Name mpa_type site_status
# 4537  Lovers Point - Julia Platt SMR      SMR   reference
# 4538  Lovers Point - Julia Platt SMR      SMR   reference
# 4539                 Carmel Bay SMCA     SMCA   reference
# 4540                 Carmel Bay SMCA     SMCA   reference
# 4541  Lovers Point - Julia Platt SMR      SMR   reference
# ...                              ...      ...         ...
# 6315                    Scorpion SMR      SMR   reference
# 6316                    Scorpion SMR      SMR         mpa
# 6317                    Scorpion SMR      SMR         mpa
# 6318                    Scorpion SMR      SMR         mpa
# 6319                    Scorpion SMR      SMR         mpa
#
# [144 rows x 6 columns]

# %%
piscoKelp = piscoKelp.merge(piscoSites, how='left', on='site')

# %%
piscoKelp = piscoKelp[piscoKelp['year'] == 2024]

# %%
piscoKelp.to_csv('data/PISCO_kelpdata.csv', index=False)
